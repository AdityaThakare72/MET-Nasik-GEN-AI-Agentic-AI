# %%
from transformers import GPT2Tokenizer, GPT2LMHeadModel
import torch

# %%
# Load pre-trained model and tokenizer
model = GPT2LMHeadModel.from_pretrained("gpt2")
tokenizer = GPT2Tokenizer.from_pretrained("gpt2")
# Out:
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %%
prompt = "The future of AI is"
input_ids = tokenizer.encode(prompt, return_tensors='pt')

# %%
# Greedy
print("Greedy:")
print(tokenizer.decode(model.generate(input_ids, max_length=50,
                                      do_sample=False)[0]))
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Greedy:
# The future of AI is uncertain. The future of AI is uncertain.
#
# The future of AI is uncertain. The future of AI is uncertain.
#
# The future of AI is uncertain. The future of AI is uncertain.
#
# The future

# %%
# Beam Search
print("Beam Search:")
print(tokenizer.decode(model.generate(input_ids,
                                      max_length=50,
                                      num_beams=5,
                                      early_stopping=True)[0]))
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Beam Search:
# The future of AI is in the hands of the next generation of scientists and engineers.
#
# The future of AI is in the hands of the next generation of scientists and engineers.
#
# The future of AI is in the hands of the next generation

# %%
# Top-K
print("Top-K Sampling:")
print(tokenizer.decode(model.generate(input_ids,
                                      do_sample=True,
                                      top_k=50,
                                      max_length=50)[0]))
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Top-K Sampling:
# The future of AI is uncertain. It does have the potential to take some of the work done by existing AI-experts, but it does so with some considerable skill and dedication. Given that we aren't talking about those who have already done AI

# %%
# Top-P
print("Top-P Sampling:")
print(tokenizer.decode(model.generate(input_ids,
                                      do_sample=True,
                                      top_p=0.7,
                                      max_length=50)[0]))
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Top-P Sampling:
# The future of AI is now at stake.
#
# A new AI model is emerging that aims to solve the problems facing society and solve our current problems. It's called Machine Learning, or Machine Learning-like Artificial Intelligence (MLI). It's

# %%
# !pip install transformers --quiet

# %% [markdown]
# # **Write your observations for the followings**

# %%
tokenizer = GPT2Tokenizer.from_pretrained("gpt2")
model = GPT2LMHeadModel.from_pretrained("gpt2")

# ✅ Set model to eval mode and ensure no gradients are computed
model.eval()
torch.no_grad()

# %%
# greedy
# Always picks the word with the highest probability at each step. No randomness.
# Prompt to generate text from
prompt_text = "In the future, artificial intelligence will"

# Tokenize input
input_ids = tokenizer.encode(prompt_text, return_tensors='pt')

# Generate text using greedy decoding (no sampling)
output_ids = model.generate(
    input_ids=input_ids,
    max_length=50,         # Total length (input + generated)
    do_sample=False        # No randomness; always pick the best next token
)

# Decode and print result
output_text = tokenizer.decode(output_ids[0], skip_special_tokens=True)
print(" Greedy Decoding Output:\n", output_text)

# %%
# Beam Search
# Explores multiple paths simultaneously and chooses the best overall sequence.
beam_output = model.generate(
    input_ids=input_ids,
    max_length=50,
    num_beams=5,             # Explore 5 possible sequences at each step
    no_repeat_ngram_size=2,  # Prevent repeating phrases
    early_stopping=True      # Stop if all beams reach the end token
)

output_text = tokenizer.decode(beam_output[0], skip_special_tokens=True)
print("🛰️ Beam Search Output:\n", output_text)

# %%
# Top-K Sampling generation
top_k_output = model.generate(
    input_ids=input_ids,
    do_sample=True,      # Enable randomness/sampling
    top_k=50,            # Sample from top 50 tokens only
    max_length=50
)

output_text = tokenizer.decode(top_k_output[0], skip_special_tokens=True)
print("🎲 Top-K Sampling Output:\n", output_text)

# %%
# Top-P Sampling (Nucleus Sampling)
top_p_output = model.generate(
    input_ids=input_ids,
    do_sample=True,      # Enable sampling
    top_p=0.9,           # Cumulative probability threshold
    top_k=0,             # Disable top-k to purely use nucleus sampling
    max_length=50
)

output_text = tokenizer.decode(top_p_output[0], skip_special_tokens=True)
print("🔮 Top-P (Nucleus) Sampling Output:\n", output_text)

# %%
# combination of top p, top k and temperature

combo_output = model.generate(
    input_ids=input_ids,
    do_sample=True,
    top_k=50,
    top_p=0.92,
    temperature=0.8,     # Lower = safer, Higher = wilder
    max_length=50
)

output_text = tokenizer.decode(combo_output[0], skip_special_tokens=True)
print("🧪 Mixed Sampling (Top-K + Top-P + Temp=0.8):\n", output_text)
