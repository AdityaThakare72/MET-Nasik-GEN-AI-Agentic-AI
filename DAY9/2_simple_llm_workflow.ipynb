# %%
from langgraph.graph import StateGraph, START, END
from langchain_google_genai import ChatGoogleGenerativeAI
from typing import TypedDict
from dotenv import load_dotenv
from langchain_groq import ChatGroq

# %%
load_dotenv()
# Out:
# True

# %%
"""model = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash-lite",
    temperature=0.7,
    max_output_tokens=50
)""";

model = ChatGroq(
    model="llama-3.1-8b-instant",
    max_tokens=50
)

# %%
# create a state

class LLMState(TypedDict):

    question: str
    answer: str

# %%
def llm_qa(state: LLMState) -> LLMState:

    # extract the question from state
    question = state['question']

    # form a prompt
    prompt = f'Answer the following question {question}'

    # ask that question to the LLM
    answer = model.invoke(prompt).content

    # update the answer in the state
    state['answer'] = answer

    return state

# %%
# create our graph

graph = StateGraph(LLMState)

# add nodes
graph.add_node('llm_qa', llm_qa)

# add edges
graph.add_edge(START, 'llm_qa')
graph.add_edge('llm_qa', END)

# compile
workflow = graph.compile()

# %%
# execute

intial_state = {'question': 'How far is India from becoming the Vishwa Guru? give me the definite answer in 2 to 3 words... and provide its reasoning '}

final_state = workflow.invoke(intial_state)

print(final_state['answer'])
# Out:
# Still a long way.
#
# Reasoning:
#
# 1. **Economic Inequality**: India still grapples with significant economic disparities, with a large portion of the population struggling to access basic necessities like education and healthcare.
# 2. **Education System**: India

# %%
model.invoke('How far is moon from the earth?').content
# Out:
# "The average distance from the Earth to the Moon is approximately 384,400 kilometers (238,900 miles). However, this distance can vary slightly due to the elliptical shape of the Moon's orbit around the Earth.\n\nAt its closest point (called"
